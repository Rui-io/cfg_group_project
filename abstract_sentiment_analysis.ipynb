# %%
import pandas as pd
import numpy as np
from textblob import TextBlob
import re
import nltk
import seaborn as sn

# %%
df = pd.read_csv('NYTGeneraldata1.csv', index_col=0)
df.head()
# Out:
#                                             abstract  \
# 0  about a fifth of the nation’s economy depends ...
# 1  as some try to lure audiences back with short ...
# 2  while big companies wield considerable power, ...
# 3  the labor department has completed a draft of ...
# 4  after months of production delays, this is the...
#
#                                             headline  \
# 0  thailand reopens to tourists from 63 countries...
# 1  a 6-hour opera in a pandemic? the met goes for...
# 2         how the pandemic has added to labor unrest
# 3  the biden administration will publish vaccine ...
# 4  the novavax vaccine, backed by operation warp ...
#
#                     pub_date
# 0  2021-11-01 12:26:03+00:00
# 1  2021-11-01 14:14:46+00:00
# 2  2021-11-01 15:06:46+00:00
# 3  2021-11-01 16:29:36+00:00
# 4  2021-11-01 16:40:48+00:00

# %%
df.dtypes
# Out:
# abstract    object
# headline    object
# pub_date    object
# dtype: object

# %% [markdown]
# ### pub_date still has datatype of object for some reason, even though we changed it in the data extraction process. Converting to date time.

# %%
df['pub_date']=pd.to_datetime(df['pub_date'])
df
# Out:
#                                               abstract  \
# 0    about a fifth of the nation’s economy depends ...
# 1    as some try to lure audiences back with short ...
# 2    while big companies wield considerable power, ...
# 3    the labor department has completed a draft of ...
# 4    after months of production delays, this is the...
# ..                                                 ...
# 361  the company said that analyses and modeling of...
# 362  intense research into the new coronavirus vari...
# 363  britain’s approach to coronavirus-related rest...
# 364  unlike alpha, beta and delta, the name of the ...
# 365  the centers for disease control and prevention...
#
#                                               headline  \
# 0    thailand reopens to tourists from 63 countries...
# 1    a 6-hour opera in a pandemic? the met goes for...
# 2           how the pandemic has added to labor unrest
# 3    the biden administration will publish vaccine ...
# 4    the novavax vaccine, backed by operation warp ...
# ..                                                 ...
# 361  regeneron says its antibody treatment may not ...
# 362         omicron: what is known — and still unknown
# 363  amid variant fears, u.k. discovers limits to i...
# 364                          how do you say ‘omicron’?
# 365  federal health officials say that they are exp...
#
#                      pub_date
# 0   2021-11-01 12:26:03+00:00
# 1   2021-11-01 14:14:46+00:00
# 2   2021-11-01 15:06:46+00:00
# 3   2021-11-01 16:29:36+00:00
# 4   2021-11-01 16:40:48+00:00
# ..                        ...
# 361 2021-11-30 16:03:10+00:00
# 362 2021-11-30 17:08:17+00:00
# 363 2021-11-30 18:14:44+00:00
# 364 2021-11-30 18:51:06+00:00
# 365 2021-11-30 19:34:18+00:00
#
# [366 rows x 3 columns]

# %%
df.dtypes
# Out:
# abstract                 object
# headline                 object
# pub_date    datetime64[ns, UTC]
# dtype: object

# %% [markdown]
# ### Adding a new date column without the UTC to see how many relevant articles there are per day (might be easier for plotting/analysis later)

# %%
df['DATE']= pd.to_datetime(df['pub_date']).dt.date
df
# Out:
#                                               abstract  \
# 0    about a fifth of the nation’s economy depends ...
# 1    as some try to lure audiences back with short ...
# 2    while big companies wield considerable power, ...
# 3    the labor department has completed a draft of ...
# 4    after months of production delays, this is the...
# ..                                                 ...
# 361  the company said that analyses and modeling of...
# 362  intense research into the new coronavirus vari...
# 363  britain’s approach to coronavirus-related rest...
# 364  unlike alpha, beta and delta, the name of the ...
# 365  the centers for disease control and prevention...
#
#                                               headline  \
# 0    thailand reopens to tourists from 63 countries...
# 1    a 6-hour opera in a pandemic? the met goes for...
# 2           how the pandemic has added to labor unrest
# 3    the biden administration will publish vaccine ...
# 4    the novavax vaccine, backed by operation warp ...
# ..                                                 ...
# 361  regeneron says its antibody treatment may not ...
# 362         omicron: what is known — and still unknown
# 363  amid variant fears, u.k. discovers limits to i...
# 364                          how do you say ‘omicron’?
# 365  federal health officials say that they are exp...
#
#                      pub_date        DATE
# 0   2021-11-01 12:26:03+00:00  2021-11-01
# 1   2021-11-01 14:14:46+00:00  2021-11-01
# 2   2021-11-01 15:06:46+00:00  2021-11-01
# 3   2021-11-01 16:29:36+00:00  2021-11-01
# 4   2021-11-01 16:40:48+00:00  2021-11-01
# ..                        ...         ...
# 361 2021-11-30 16:03:10+00:00  2021-11-30
# 362 2021-11-30 17:08:17+00:00  2021-11-30
# 363 2021-11-30 18:14:44+00:00  2021-11-30
# 364 2021-11-30 18:51:06+00:00  2021-11-30
# 365 2021-11-30 19:34:18+00:00  2021-11-30
#
# [366 rows x 4 columns]

# %%
df.dtypes
# Out:
# abstract                 object
# headline                 object
# pub_date    datetime64[ns, UTC]
# DATE                     object
# dtype: object

# %%
df['DATE']=pd.to_datetime(df['DATE'])

# %%
df.dtypes
# Out:
# abstract                 object
# headline                 object
# pub_date    datetime64[ns, UTC]
# DATE             datetime64[ns]
# dtype: object

# %% [markdown]
# ### Number of covid related articles per day

# %%
count=df.groupby('DATE').size()
count
# Out:
# DATE
# 2021-11-01     9
# 2021-11-02    15
# 2021-11-03    19
# 2021-11-04    20
# 2021-11-05    11
# 2021-11-06     5
# 2021-11-07     4
# 2021-11-08    11
# 2021-11-09    16
# 2021-11-10     9
# 2021-11-11     8
# 2021-11-12     8
# 2021-11-13    10
# 2021-11-14     6
# 2021-11-15    11
# 2021-11-16    16
# 2021-11-17    21
# 2021-11-18    17
# 2021-11-19     9
# 2021-11-20    11
# 2021-11-21     8
# 2021-11-22    10
# 2021-11-23    16
# 2021-11-24    15
# 2021-11-25     6
# 2021-11-26    14
# 2021-11-27    11
# 2021-11-28    13
# 2021-11-29    22
# 2021-11-30    15
# dtype: int64

# %% [markdown]
# ### Using TextBlob to find polarity and subjectivity sentiment of abstract
# #### Sugya's code! Thank you!

# %%
polarity=lambda x: TextBlob(x).sentiment.polarity
subjectivity=lambda x: TextBlob(x).sentiment.subjectivity
df['Abstract Polarity']=df['abstract'].apply(polarity)
df['Abstract Subjectivity']=df['abstract'].apply(subjectivity)
df
# Out:
#                                               abstract  \
# 0    about a fifth of the nation’s economy depends ...
# 1    as some try to lure audiences back with short ...
# 2    while big companies wield considerable power, ...
# 3    the labor department has completed a draft of ...
# 4    after months of production delays, this is the...
# ..                                                 ...
# 361  the company said that analyses and modeling of...
# 362  intense research into the new coronavirus vari...
# 363  britain’s approach to coronavirus-related rest...
# 364  unlike alpha, beta and delta, the name of the ...
# 365  the centers for disease control and prevention...
#
#                                               headline  \
# 0    thailand reopens to tourists from 63 countries...
# 1    a 6-hour opera in a pandemic? the met goes for...
# 2           how the pandemic has added to labor unrest
# 3    the biden administration will publish vaccine ...
# 4    the novavax vaccine, backed by operation warp ...
# ..                                                 ...
# 361  regeneron says its antibody treatment may not ...
# 362         omicron: what is known — and still unknown
# 363  amid variant fears, u.k. discovers limits to i...
# 364                          how do you say ‘omicron’?
# 365  federal health officials say that they are exp...
#
#                      pub_date       DATE  Abstract Polarity  \
# 0   2021-11-01 12:26:03+00:00 2021-11-01           0.300000
# 1   2021-11-01 14:14:46+00:00 2021-11-01           0.000000
# 2   2021-11-01 15:06:46+00:00 2021-11-01           0.087273
# 3   2021-11-01 16:29:36+00:00 2021-11-01          -0.033333
# 4   2021-11-01 16:40:48+00:00 2021-11-01           0.250000
# ..                        ...        ...                ...
# 361 2021-11-30 16:03:10+00:00 2021-11-30           0.350000
# 362 2021-11-30 17:08:17+00:00 2021-11-30           0.146591
# 363 2021-11-30 18:14:44+00:00 2021-11-30          -0.008333
# 364 2021-11-30 18:51:06+00:00 2021-11-30           0.291667
# 365 2021-11-30 19:34:18+00:00 2021-11-30          -0.016667
#
#      Abstract Subjectivity
# 0                 0.450000
# 1                 0.150000
# 2                 0.290909
# 3                 0.133333
# 4                 0.333333
# ..                     ...
# 361               0.550000
# 362               0.446970
# 363               0.158333
# 364               0.425000
# 365               0.800000
#
# [366 rows x 6 columns]

# %% [markdown]
# ### Categorising abstract polarity

# %%
def calculate_polarity(Polarity):
        if Polarity > 0.75:
            return "Extremely positive"
        elif Polarity > 0.5:
            return "Significantly positive"
        elif Polarity > 0.3:
            return "Fairly positive"
        elif Polarity > 0.1:
            return "Slightly positive"
        elif Polarity < -0.1:
            return "Slightly negative"
        elif Polarity < -0.3:
            return "Fairly negative"
        elif Polarity < -0.5:
            return "Significantly negative"
        elif Polarity < -0.75:
            return "Extremely negative"
        else:
            return "Neutral"
df['Polarity Category'] = df['Abstract Polarity'].apply(calculate_polarity)
df
# Out:
#                                               abstract  \
# 0    about a fifth of the nation’s economy depends ...
# 1    as some try to lure audiences back with short ...
# 2    while big companies wield considerable power, ...
# 3    the labor department has completed a draft of ...
# 4    after months of production delays, this is the...
# ..                                                 ...
# 361  the company said that analyses and modeling of...
# 362  intense research into the new coronavirus vari...
# 363  britain’s approach to coronavirus-related rest...
# 364  unlike alpha, beta and delta, the name of the ...
# 365  the centers for disease control and prevention...
#
#                                               headline  \
# 0    thailand reopens to tourists from 63 countries...
# 1    a 6-hour opera in a pandemic? the met goes for...
# 2           how the pandemic has added to labor unrest
# 3    the biden administration will publish vaccine ...
# 4    the novavax vaccine, backed by operation warp ...
# ..                                                 ...
# 361  regeneron says its antibody treatment may not ...
# 362         omicron: what is known — and still unknown
# 363  amid variant fears, u.k. discovers limits to i...
# 364                          how do you say ‘omicron’?
# 365  federal health officials say that they are exp...
#
#                      pub_date       DATE  Abstract Polarity  \
# 0   2021-11-01 12:26:03+00:00 2021-11-01           0.300000
# 1   2021-11-01 14:14:46+00:00 2021-11-01           0.000000
# 2   2021-11-01 15:06:46+00:00 2021-11-01           0.087273
# 3   2021-11-01 16:29:36+00:00 2021-11-01          -0.033333
# 4   2021-11-01 16:40:48+00:00 2021-11-01           0.250000
# ..                        ...        ...                ...
# 361 2021-11-30 16:03:10+00:00 2021-11-30           0.350000
# 362 2021-11-30 17:08:17+00:00 2021-11-30           0.146591
# 363 2021-11-30 18:14:44+00:00 2021-11-30          -0.008333
# 364 2021-11-30 18:51:06+00:00 2021-11-30           0.291667
# 365 2021-11-30 19:34:18+00:00 2021-11-30          -0.016667
#
#      Abstract Subjectivity  Polarity Category
# 0                 0.450000  Slightly positive
# 1                 0.150000            Neutral
# 2                 0.290909            Neutral
# 3                 0.133333            Neutral
# 4                 0.333333  Slightly positive
# ..                     ...                ...
# 361               0.550000    Fairly positive
# 362               0.446970  Slightly positive
# 363               0.158333            Neutral
# 364               0.425000  Slightly positive
# 365               0.800000            Neutral
#
# [366 rows x 7 columns]

# %% [markdown]
# ### Categorising abstract subjectivity

# %%
def calculate_subjectivity(subjectivity):
        if subjectivity > 0.75:
            return "Extremely subjective"
        elif subjectivity > 0.5:
            return "Fairly subjective"
        elif subjectivity > 0.3:
            return "Fairly objective"
        elif subjectivity > 0.1:
            return "Extremely objective"   
df['Abstract Subjectivity Category'] = df['Abstract Subjectivity'].apply(calculate_subjectivity)
df.head()
# Out:
#                                             abstract  \
# 0  about a fifth of the nation’s economy depends ...
# 1  as some try to lure audiences back with short ...
# 2  while big companies wield considerable power, ...
# 3  the labor department has completed a draft of ...
# 4  after months of production delays, this is the...
#
#                                             headline  \
# 0  thailand reopens to tourists from 63 countries...
# 1  a 6-hour opera in a pandemic? the met goes for...
# 2         how the pandemic has added to labor unrest
# 3  the biden administration will publish vaccine ...
# 4  the novavax vaccine, backed by operation warp ...
#
#                    pub_date       DATE  Abstract Polarity  \
# 0 2021-11-01 12:26:03+00:00 2021-11-01           0.300000
# 1 2021-11-01 14:14:46+00:00 2021-11-01           0.000000
# 2 2021-11-01 15:06:46+00:00 2021-11-01           0.087273
# 3 2021-11-01 16:29:36+00:00 2021-11-01          -0.033333
# 4 2021-11-01 16:40:48+00:00 2021-11-01           0.250000
#
#    Abstract Subjectivity  Polarity Category Abstract Subjectivity Category
# 0               0.450000  Slightly positive               Fairly objective
# 1               0.150000            Neutral            Extremely objective
# 2               0.290909            Neutral            Extremely objective
# 3               0.133333            Neutral            Extremely objective
# 4               0.333333  Slightly positive               Fairly objective

# %% [markdown]
# ### Reordering columns for ease of interpretation

# %%
df=df[['pub_date','DATE','headline','abstract','Abstract Polarity','Polarity Category','Abstract Subjectivity','Abstract Subjectivity Category']]
df.head()
# Out:
#                    pub_date       DATE  \
# 0 2021-11-01 12:26:03+00:00 2021-11-01
# 1 2021-11-01 14:14:46+00:00 2021-11-01
# 2 2021-11-01 15:06:46+00:00 2021-11-01
# 3 2021-11-01 16:29:36+00:00 2021-11-01
# 4 2021-11-01 16:40:48+00:00 2021-11-01
#
#                                             headline  \
# 0  thailand reopens to tourists from 63 countries...
# 1  a 6-hour opera in a pandemic? the met goes for...
# 2         how the pandemic has added to labor unrest
# 3  the biden administration will publish vaccine ...
# 4  the novavax vaccine, backed by operation warp ...
#
#                                             abstract  Abstract Polarity  \
# 0  about a fifth of the nation’s economy depends ...           0.300000
# 1  as some try to lure audiences back with short ...           0.000000
# 2  while big companies wield considerable power, ...           0.087273
# 3  the labor department has completed a draft of ...          -0.033333
# 4  after months of production delays, this is the...           0.250000
#
#    Polarity Category  Abstract Subjectivity Abstract Subjectivity Category
# 0  Slightly positive               0.450000               Fairly objective
# 1            Neutral               0.150000            Extremely objective
# 2            Neutral               0.290909            Extremely objective
# 3            Neutral               0.133333            Extremely objective
# 4  Slightly positive               0.333333               Fairly objective

# %% [markdown]
# ### Mean abstract polarity and subjectivity for each day of the month

# %%
df.groupby('DATE').mean()
# Out:
#             Abstract Polarity  Abstract Subjectivity
# DATE
# 2021-11-01           0.095561               0.290903
# 2021-11-02           0.050026               0.312923
# 2021-11-03           0.074514               0.356148
# 2021-11-04           0.029312               0.346657
# 2021-11-05           0.015987               0.290618
# 2021-11-06           0.158333               0.304167
# 2021-11-07           0.248030               0.405606
# 2021-11-08          -0.011240               0.241670
# 2021-11-09           0.083969               0.276681
# 2021-11-10          -0.003889               0.331235
# 2021-11-11           0.042835               0.213731
# 2021-11-12           0.037388               0.261223
# 2021-11-13          -0.073750               0.269167
# 2021-11-14           0.077609               0.248022
# 2021-11-15           0.106198               0.295661
# 2021-11-16           0.154955               0.283454
# 2021-11-17           0.054029               0.343432
# 2021-11-18           0.058467               0.253784
# 2021-11-19           0.113519               0.325370
# 2021-11-20           0.012022               0.278880
# 2021-11-21           0.014773               0.263826
# 2021-11-22           0.083624               0.323213
# 2021-11-23           0.094403               0.231383
# 2021-11-24           0.001959               0.221754
# 2021-11-25           0.027375               0.344204
# 2021-11-26           0.068236               0.336878
# 2021-11-27           0.138671               0.344054
# 2021-11-28           0.184557               0.425874
# 2021-11-29           0.142198               0.397967
# 2021-11-30           0.117257               0.443072
