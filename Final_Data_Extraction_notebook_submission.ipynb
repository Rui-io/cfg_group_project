# %% [markdown]
# # <u> Data Extraction

# %%
# Libraries you may need to install
# pip install alpha_vantage
# pip install textblob
# pip install pprint
# pip install pandas
# pip install regex
# pip install nltk
# pip install numpy
# pip install matplotlib
# pip install string

# %%
#Importing modules needed
import requests
from pprint import pprint as pp
import pandas as pd
import re
import datetime
from alpha_vantage.timeseries import TimeSeries
import csv
import string

# %% [markdown]
# # Introduction
# #### For our analysis, we will be using the following data:
# <ul>
#     <li>NYT Data: Headlines, abstracts and published dates of New York Times articles, using the New York Times API. We will separate this into two CSVs for later analysis - one with articles from 2021, and one with articles from November 2021 only
#     <li>Finance Data: Financial market data for 3 large pharmaceutical companies (Astrazeneca, Pfizer and Moderna), using the Alpha Vantage API
#     <li>Guardian Data: Headlines and published dates of Guardian articles about covid, using the Guardian API. We will also extract word frequencies of commonly used words in Guardian article headlines, for each quarter of the year 2021.

# %% [markdown]
# # NYT Data
#
# ## 2021 Articles
# #### Getting data from NewYorkTimes API for the year 2021. API for NewYorkTimes only returns result for a month. Hence, we use for loop so that it runs through each month and appends the data returned
# #### Writing the obtained data to csv file named 'NYT_UnfilteredData.csv'
#
# NB You may need to restart the kernel and run this cell again if you run into errors - this is due to an issue with the API.

# %%
year='2021'
# month=1

column_list=['abstract', 'web_url', 'snippet', 'lead_paragraph', 'print_section',
       'print_page', 'source', 'multimedia', 'headline', 'keywords',
       'pub_date', 'document_type', 'news_desk', 'section_name', 'byline',
       'type_of_material', '_id', 'word_count', 'uri', 'subsection_name']

appid='tmGtDzyAKd4oBddx3xJMNnycRGHhj0hM'#use personal api id

df1=pd.DataFrame(columns=column_list)

for i in range(1,12):
    endpoint1=('https://api.nytimes.com/svc/archive/v1/{}/{}.json?api-key={}'.format(year, i,appid))
    response=requests.get(endpoint1)
    data=response.json()
    dataextract=data['response']['docs']
    
    df1=df1.append(dataextract, ignore_index=True)
df1.head()
# Out:
#                                             abstract  \
# 0     Reasons to be hopeful about the Biden economy.
# 1  The video shows a man raising something to his...
# 2  Every December since 2017, Ada Rojas has guide...
# 3  The suit, led by Representative Louie Gohmert ...
# 4  The United States recorded its 20 millionth ca...
#
#                                              web_url  \
# 0  https://www.nytimes.com/2020/12/31/opinion/202...
# 1  https://www.nytimes.com/2020/12/31/us/george-f...
# 2  https://www.nytimes.com/2020/12/31/us/resolvin...
# 3  https://www.nytimes.com/2020/12/31/us/politics...
# 4  https://www.nytimes.com/2020/12/31/world/the-u...
#
#                                              snippet  \
# 0     Reasons to be hopeful about the Biden economy.
# 1  The video shows a man raising something to his...
# 2
# 3  The suit, led by Representative Louie Gohmert ...
# 4
#
#                                       lead_paragraph print_section print_page  \
# 0  The next few months will be hell in terms of p...             A         18
# 1  The Minneapolis Police Department released bod...             A         17
# 2  Every December since 2017, Ada Rojas has guide...           NaN        NaN
# 3  [Here’s what you need to know about President-...           NaN        NaN
# 4  The United States recorded its 20 millionth ca...           NaN        NaN
#
#                source                                         multimedia  \
# 0  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 1  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 3  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 4  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
#
#                                             headline  \
# 0  {'main': 'Things Will Get Better. Seriously.',...
# 1  {'main': 'Minneapolis Police Release Body Came...
# 2  {'main': 'Resolving to live a lot better than ...
# 3  {'main': 'Justice Dept. Asks Judge to Toss Ele...
# 4  {'main': 'The U.S. reaches 20 million cases.',...
#
#                                             keywords  \
# 0  [{'name': 'persons', 'value': 'Biden, Joseph R...
# 1  [{'name': 'persons', 'value': 'Idd, Dolal B', ...
# 2                                                 []
# 3  [{'name': 'organizations', 'value': 'Justice D...
# 4  [{'name': 'subject', 'value': 'internal-essent...
#
#                    pub_date document_type   news_desk section_name  \
# 0  2021-01-01T00:00:09+0000       article        OpEd      Opinion
# 1  2021-01-01T00:16:53+0000       article    National         U.S.
# 2  2021-01-01T00:58:19+0000       article     Express         U.S.
# 3  2021-01-01T01:24:55+0000       article  Washington         U.S.
# 4  2021-01-01T01:28:22+0000       article     Foreign        World
#
#                                               byline type_of_material  \
# 0  {'original': 'By Paul Krugman', 'person': [{'f...            Op-Ed
# 1  {'original': 'By Nicholas Bogel-Burroughs', 'p...             News
# 2  {'original': 'By Concepción de León', 'person'...             News
# 3  {'original': 'By Maggie Haberman and Katie Ben...             News
# 4  {'original': 'By Kate Taylor', 'person': [{'fi...             News
#
#                                                  _id word_count  \
# 0  nyt://article/ab590671-f1be-5b6d-8212-a7d18aab...        882
# 1  nyt://article/8f633850-09ab-53ff-8753-bc72eaba...        861
# 2  nyt://article/35e85454-abfc-5376-b4b5-7d99316d...        263
# 3  nyt://article/5fc45bbd-d622-56da-875c-b5b7c4ef...        695
# 4  nyt://article/d75205a5-201f-5dc3-b8fe-278c3d64...        438
#
#                                                  uri subsection_name
# 0  nyt://article/ab590671-f1be-5b6d-8212-a7d18aab...             NaN
# 1  nyt://article/8f633850-09ab-53ff-8753-bc72eaba...             NaN
# 2  nyt://article/35e85454-abfc-5376-b4b5-7d99316d...             NaN
# 3  nyt://article/5fc45bbd-d622-56da-875c-b5b7c4ef...        Politics
# 4  nyt://article/d75205a5-201f-5dc3-b8fe-278c3d64...             NaN

# %%
#df1.to_csv('NYT_UnfilteredData.csv')

# %% [markdown]
# #### Converting content of abstract column to all lowercase

# %%
df1['abstract']=df1['abstract'].str.lower()
df1.head()
# Out:
#                                             abstract  \
# 0     reasons to be hopeful about the biden economy.
# 1  the video shows a man raising something to his...
# 2  every december since 2017, ada rojas has guide...
# 3  the suit, led by representative louie gohmert ...
# 4  the united states recorded its 20 millionth ca...
#
#                                              web_url  \
# 0  https://www.nytimes.com/2020/12/31/opinion/202...
# 1  https://www.nytimes.com/2020/12/31/us/george-f...
# 2  https://www.nytimes.com/2020/12/31/us/resolvin...
# 3  https://www.nytimes.com/2020/12/31/us/politics...
# 4  https://www.nytimes.com/2020/12/31/world/the-u...
#
#                                              snippet  \
# 0     Reasons to be hopeful about the Biden economy.
# 1  The video shows a man raising something to his...
# 2
# 3  The suit, led by Representative Louie Gohmert ...
# 4
#
#                                       lead_paragraph print_section print_page  \
# 0  The next few months will be hell in terms of p...             A         18
# 1  The Minneapolis Police Department released bod...             A         17
# 2  Every December since 2017, Ada Rojas has guide...           NaN        NaN
# 3  [Here’s what you need to know about President-...           NaN        NaN
# 4  The United States recorded its 20 millionth ca...           NaN        NaN
#
#                source                                         multimedia  \
# 0  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 1  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 3  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 4  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
#
#                                             headline  \
# 0  {'main': 'Things Will Get Better. Seriously.',...
# 1  {'main': 'Minneapolis Police Release Body Came...
# 2  {'main': 'Resolving to live a lot better than ...
# 3  {'main': 'Justice Dept. Asks Judge to Toss Ele...
# 4  {'main': 'The U.S. reaches 20 million cases.',...
#
#                                             keywords  \
# 0  [{'name': 'persons', 'value': 'Biden, Joseph R...
# 1  [{'name': 'persons', 'value': 'Idd, Dolal B', ...
# 2                                                 []
# 3  [{'name': 'organizations', 'value': 'Justice D...
# 4  [{'name': 'subject', 'value': 'internal-essent...
#
#                    pub_date document_type   news_desk section_name  \
# 0  2021-01-01T00:00:09+0000       article        OpEd      Opinion
# 1  2021-01-01T00:16:53+0000       article    National         U.S.
# 2  2021-01-01T00:58:19+0000       article     Express         U.S.
# 3  2021-01-01T01:24:55+0000       article  Washington         U.S.
# 4  2021-01-01T01:28:22+0000       article     Foreign        World
#
#                                               byline type_of_material  \
# 0  {'original': 'By Paul Krugman', 'person': [{'f...            Op-Ed
# 1  {'original': 'By Nicholas Bogel-Burroughs', 'p...             News
# 2  {'original': 'By Concepción de León', 'person'...             News
# 3  {'original': 'By Maggie Haberman and Katie Ben...             News
# 4  {'original': 'By Kate Taylor', 'person': [{'fi...             News
#
#                                                  _id word_count  \
# 0  nyt://article/ab590671-f1be-5b6d-8212-a7d18aab...        882
# 1  nyt://article/8f633850-09ab-53ff-8753-bc72eaba...        861
# 2  nyt://article/35e85454-abfc-5376-b4b5-7d99316d...        263
# 3  nyt://article/5fc45bbd-d622-56da-875c-b5b7c4ef...        695
# 4  nyt://article/d75205a5-201f-5dc3-b8fe-278c3d64...        438
#
#                                                  uri subsection_name
# 0  nyt://article/ab590671-f1be-5b6d-8212-a7d18aab...             NaN
# 1  nyt://article/8f633850-09ab-53ff-8753-bc72eaba...             NaN
# 2  nyt://article/35e85454-abfc-5376-b4b5-7d99316d...             NaN
# 3  nyt://article/5fc45bbd-d622-56da-875c-b5b7c4ef...        Politics
# 4  nyt://article/d75205a5-201f-5dc3-b8fe-278c3d64...             NaN

# %% [markdown]
# #### Filtering the rows of data where the abstract contains words within the list 'words'
# #### Writing the obtained dataframe to csv file named 'NYTGeneraldata2.csv'

# %%
words = ['covid','pandemic','coronavirus','vaccine','health','lockdown','restriction','quarantine','delta','omicron','variant']

df2=df1[df1['abstract'].str.contains('|'.join(words))]

# %% [markdown]
# #### Filtering the dataframe so that it only has two columns; 'abstract', 'pub_date' along with index

# %%
df3=df2.filter(['abstract','pub_date'])

# %%
df3.reset_index(drop=True, inplace=True)

# %% [markdown]
# #### Converting the 'pub_date' to datetime data type,

# %%
df3['pub_date']= pd.to_datetime(df3['pub_date'], format = "%Y-%m-%d %H:%M:%S", utc = True)
df3
# Out:
#                                                abstract  \
# 0     the united states recorded its 20 millionth ca...
# 1     throughout the coronavirus pandemic, well-atte...
# 2     a highly contagious coronavirus variant first ...
# 3     the pandemic caused the cancellation of the ro...
# 4     with a new variant of the virus emerging elsew...
# ...                                                 ...
# 7951  slowed but not stopped by the pandemic, wilson...
# 7952  intense research into the new coronavirus vari...
# 7953  britain’s approach to coronavirus-related rest...
# 7954  unlike alpha, beta and delta, the name of the ...
# 7955  the centers for disease control and prevention...
#
#                       pub_date
# 0    2021-01-01 01:28:22+00:00
# 1    2021-01-01 03:08:25+00:00
# 2    2021-01-01 03:44:59+00:00
# 3    2021-01-01 04:24:17+00:00
# 4    2021-01-01 08:00:06+00:00
# ...                        ...
# 7951 2021-11-30 16:14:32+00:00
# 7952 2021-11-30 17:08:17+00:00
# 7953 2021-11-30 18:14:44+00:00
# 7954 2021-11-30 18:51:06+00:00
# 7955 2021-11-30 19:34:18+00:00
#
# [7956 rows x 2 columns]

# %% [markdown]
# #### Writing the obtained dataframe to csv file named 'NYTGeneraldata2.csv'

# %%
df3.to_csv('data/NYTGeneraldata2.csv')

# %%
### code for november extraction with headline and abstract

# %%
df4 = df1
a=df4.headline
b=[]
for i in a.index:
    b.append(a[i]['main'])

df4['headline']=b
df4['headline']=df4['headline'].str.lower()
df4
# Out:
#                                                 abstract  \
# 0         reasons to be hopeful about the biden economy.
# 1      the video shows a man raising something to his...
# 2      every december since 2017, ada rojas has guide...
# 3      the suit, led by representative louie gohmert ...
# 4      the united states recorded its 20 millionth ca...
# ...                                                  ...
# 50591  claire keegan’s “small things like these” unco...
# 50592  the centers for disease control and prevention...
# 50593  emma coronel aispuro pleaded guilty in june to...
# 50594  “i think it’s important that the i.r.s. have v...
# 50595  david marcus had most recently spearheaded met...
#
#                                                  web_url  \
# 0      https://www.nytimes.com/2020/12/31/opinion/202...
# 1      https://www.nytimes.com/2020/12/31/us/george-f...
# 2      https://www.nytimes.com/2020/12/31/us/resolvin...
# 3      https://www.nytimes.com/2020/12/31/us/politics...
# 4      https://www.nytimes.com/2020/12/31/world/the-u...
# ...                                                  ...
# 50591  https://www.nytimes.com/2021/11/30/books/revie...
# 50592  https://www.nytimes.com/2021/11/30/us/politics...
# 50593  https://www.nytimes.com/2021/11/30/us/politics...
# 50594  https://www.nytimes.com/2021/11/30/business/ir...
# 50595  https://www.nytimes.com/2021/11/30/technology/...
#
#                                                  snippet  \
# 0         Reasons to be hopeful about the Biden economy.
# 1      The video shows a man raising something to his...
# 2
# 3      The suit, led by Representative Louie Gohmert ...
# 4
# ...                                                  ...
# 50591  Claire Keegan’s “Small Things Like These” unco...
# 50592  The Centers for Disease Control and Prevention...
# 50593  Emma Coronel Aispuro pleaded guilty in June to...
# 50594  “I think it’s important that the I.R.S. have v...
# 50595  David Marcus had most recently spearheaded Met...
#
#                                           lead_paragraph print_section  \
# 0      The next few months will be hell in terms of p...             A
# 1      The Minneapolis Police Department released bod...             A
# 2      Every December since 2017, Ada Rojas has guide...           NaN
# 3      [Here’s what you need to know about President-...           NaN
# 4      The United States recorded its 20 millionth ca...           NaN
# ...                                                  ...           ...
# 50591           SMALL THINGS LIKE THESE By Claire Keegan           NaN
# 50592  Top federal health officials said on Tuesday t...           NaN
# 50593  Emma Coronel Aispuro, the wife of the notoriou...           NaN
# 50594  WASHINGTON — Treasury Secretary Janet L. Yelle...           NaN
# 50595  David Marcus, the leader of cryptocurrency eff...           NaN
#
#       print_page              source  \
# 0             18  The New York Times
# 1             17  The New York Times
# 2            NaN  The New York Times
# 3            NaN  The New York Times
# 4            NaN  The New York Times
# ...          ...                 ...
# 50591        NaN  The New York Times
# 50592        NaN  The New York Times
# 50593        NaN  The New York Times
# 50594        NaN  The New York Times
# 50595        NaN  The New York Times
#
#                                               multimedia  \
# 0      [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 1      [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2      [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 3      [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 4      [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# ...                                                  ...
# 50591  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 50592  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 50593  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 50594  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 50595                                                 []
#
#                                                 headline  \
# 0                     things will get better. seriously.
# 1      minneapolis police release body camera video o...
# 2           resolving to live a lot better than in 2020.
# 3      justice dept. asks judge to toss election laws...
# 4                     the u.s. reaches 20 million cases.
# ...                                                  ...
# 50591  the horrors of irish magdalene laundries, revi...
# 50592  federal health officials say that they are exp...
# 50593     el chapo’s wife sentenced to 3 years in prison
# 50594  janet yellen still supports a plan to make ban...
# 50595  the head of meta’s cryptocurrency efforts is l...
#
#                                                 keywords  \
# 0      [{'name': 'persons', 'value': 'Biden, Joseph R...
# 1      [{'name': 'persons', 'value': 'Idd, Dolal B', ...
# 2                                                     []
# 3      [{'name': 'organizations', 'value': 'Justice D...
# 4      [{'name': 'subject', 'value': 'internal-essent...
# ...                                                  ...
# 50591  [{'name': 'subject', 'value': 'Books and Liter...
# 50592  [{'name': 'subject', 'value': 'Coronavirus Omi...
# 50593  [{'name': 'subject', 'value': 'Drug Abuse and ...
# 50594  [{'name': 'persons', 'value': 'Yellen, Janet L...
# 50595  [{'name': 'subject', 'value': 'Virtual Currenc...
#
#                        pub_date document_type   news_desk  section_name  \
# 0      2021-01-01T00:00:09+0000       article        OpEd       Opinion
# 1      2021-01-01T00:16:53+0000       article    National          U.S.
# 2      2021-01-01T00:58:19+0000       article     Express          U.S.
# 3      2021-01-01T01:24:55+0000       article  Washington          U.S.
# 4      2021-01-01T01:28:22+0000       article     Foreign         World
# ...                         ...           ...         ...           ...
# 50591  2021-11-30T19:13:07+0000       article  BookReview         Books
# 50592  2021-11-30T19:34:18+0000       article  Washington          U.S.
# 50593  2021-11-30T19:34:33+0000       article  Washington          U.S.
# 50594  2021-11-30T19:38:16+0000       article    Business  Business Day
# 50595  2021-11-30T19:46:56+0000       article    Business    Technology
#
#                                                   byline type_of_material  \
# 0      {'original': 'By Paul Krugman', 'person': [{'f...            Op-Ed
# 1      {'original': 'By Nicholas Bogel-Burroughs', 'p...             News
# 2      {'original': 'By Concepción de León', 'person'...             News
# 3      {'original': 'By Maggie Haberman and Katie Ben...             News
# 4      {'original': 'By Kate Taylor', 'person': [{'fi...             News
# ...                                                  ...              ...
# 50591  {'original': 'By Lydia Millet', 'person': [{'f...           Review
# 50592  {'original': 'By Noah Weiland', 'person': [{'f...             News
# 50593  {'original': 'By Alan Feuer', 'person': [{'fir...             News
# 50594  {'original': 'By Alan Rappeport', 'person': [{...             News
# 50595  {'original': 'By Mike Isaac', 'person': [{'fir...             News
#
#                                                      _id word_count  \
# 0      nyt://article/ab590671-f1be-5b6d-8212-a7d18aab...        882
# 1      nyt://article/8f633850-09ab-53ff-8753-bc72eaba...        861
# 2      nyt://article/35e85454-abfc-5376-b4b5-7d99316d...        263
# 3      nyt://article/5fc45bbd-d622-56da-875c-b5b7c4ef...        695
# 4      nyt://article/d75205a5-201f-5dc3-b8fe-278c3d64...        438
# ...                                                  ...        ...
# 50591  nyt://article/02e3b75d-49de-51c4-859c-4e4a85b6...        678
# 50592  nyt://article/324cab09-d56f-5fdf-9fb2-09ddcb1e...        619
# 50593  nyt://article/69ef883b-535a-5e9e-8188-52aacb82...        743
# 50594  nyt://article/18242ec4-293a-5eb7-8f8c-b272cfb2...        443
# 50595  nyt://article/fc55cf3a-e039-5a6d-ab6b-376fcc23...        342
#
#                                                      uri subsection_name
# 0      nyt://article/ab590671-f1be-5b6d-8212-a7d18aab...             NaN
# 1      nyt://article/8f633850-09ab-53ff-8753-bc72eaba...             NaN
# 2      nyt://article/35e85454-abfc-5376-b4b5-7d99316d...             NaN
# 3      nyt://article/5fc45bbd-d622-56da-875c-b5b7c4ef...        Politics
# 4      nyt://article/d75205a5-201f-5dc3-b8fe-278c3d64...             NaN
# ...                                                  ...             ...
# 50591  nyt://article/02e3b75d-49de-51c4-859c-4e4a85b6...     Book Review
# 50592  nyt://article/324cab09-d56f-5fdf-9fb2-09ddcb1e...        Politics
# 50593  nyt://article/69ef883b-535a-5e9e-8188-52aacb82...        Politics
# 50594  nyt://article/18242ec4-293a-5eb7-8f8c-b272cfb2...             NaN
# 50595  nyt://article/fc55cf3a-e039-5a6d-ab6b-376fcc23...             NaN
#
# [50596 rows x 20 columns]

# %%
words = ['covid','pandemic','coronavirus','vaccine','health','lockdown','restriction','quarantine','delta','omicron','variant']

df5=df4[df4['headline'].str.contains('|'.join(words))]
df5
# Out:
#                                                 abstract  \
# 11     a highly contagious coronavirus variant first ...
# 16     with a new variant of the virus emerging elsew...
# 18       test your knowledge of this week’s health news.
# 24     our 7-day well challenge will show you how to ...
# 47     the coronavirus has disrupted supply chains in...
# ...                                                  ...
# 50566  the company said that analyses and modeling of...
# 50575  intense research into the new coronavirus vari...
# 50581  britain’s approach to coronavirus-related rest...
# 50587  unlike alpha, beta and delta, the name of the ...
# 50592  the centers for disease control and prevention...
#
#                                                  web_url  \
# 11     https://www.nytimes.com/2020/12/31/world/flori...
# 16     https://www.nytimes.com/2021/01/01/nyregion/ny...
# 18     https://www.nytimes.com/interactive/2021/01/01...
# 24     https://www.nytimes.com/2021/01/01/well/live/n...
# 47     https://www.nytimes.com/2021/01/01/realestate/...
# ...                                                  ...
# 50566  https://www.nytimes.com/2021/11/30/health/rege...
# 50575  https://www.nytimes.com/article/omicron-corona...
# 50581  https://www.nytimes.com/2021/11/30/world/europ...
# 50587  https://www.nytimes.com/2021/11/30/world/omicr...
# 50592  https://www.nytimes.com/2021/11/30/us/politics...
#
#                                                  snippet  \
# 11
# 16     With a new variant of the virus emerging elsew...
# 18       Test your knowledge of this week’s health news.
# 24     Our 7-Day Well Challenge will show you how to ...
# 47     The coronavirus has disrupted supply chains in...
# ...                                                  ...
# 50566  The company said that analyses and modeling of...
# 50575  Intense research into the new coronavirus vari...
# 50581  Britain’s approach to coronavirus-related rest...
# 50587  Unlike Alpha, Beta and Delta, the name of the ...
# 50592  The Centers for Disease Control and Prevention...
#
#                                           lead_paragraph print_section  \
# 11     A highly contagious coronavirus variant first ...           NaN
# 16     As the final hours ticked away in a harrowing ...             A
# 18       Test your knowledge of this week’s health news.           NaN
# 24     Here’s a better way to start the new year: Ski...             D
# 47     Shopping for a dishwasher isn’t what it used t...            RE
# ...                                                  ...           ...
# 50566  Regeneron said on Tuesday that its Covid-19 an...           NaN
# 50575  First identified in Botswana and South Africa,...             A
# 50581  LONDON — At almost every step of the pandemic,...           NaN
# 50587  Among the many unknowns surrounding the new co...           NaN
# 50592  Top federal health officials said on Tuesday t...           NaN
#
#       print_page              source  \
# 11           NaN  The New York Times
# 16             5  The New York Times
# 18           NaN  The New York Times
# 24             6  The New York Times
# 47             4  The New York Times
# ...          ...                 ...
# 50566        NaN  The New York Times
# 50575         12  The New York Times
# 50581        NaN  The New York Times
# 50587        NaN  The New York Times
# 50592        NaN  The New York Times
#
#                                               multimedia  \
# 11     [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 16     [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 18     [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 24     [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 47     [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# ...                                                  ...
# 50566  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 50575  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 50581  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 50587  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 50592  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
#
#                                                 headline  \
# 11     florida health officials detect the state’s fi...
# 16     virus numbers are surging. why is new york’s v...
# 18     weekly health quiz: a new coronavirus variant,...
# 24     for a healthier 2021, keep the best habits of ...
# 47     furnishing your home in a pandemic will requir...
# ...                                                  ...
# 50566  regeneron says its antibody treatment may not ...
# 50575         omicron: what is known — and still unknown
# 50581  amid variant fears, u.k. discovers limits to i...
# 50587                          how do you say ‘omicron’?
# 50592  federal health officials say that they are exp...
#
#                                                 keywords  \
# 11     [{'name': 'subject', 'value': 'internal-essent...
# 16     [{'name': 'subject', 'value': 'Coronavirus (20...
# 18     [{'name': 'subject', 'value': 'Exercise', 'ran...
# 24     [{'name': 'subject', 'value': 'Content Type: S...
# 47     [{'name': 'subject', 'value': 'Real Estate and...
# ...                                                  ...
# 50566  [{'name': 'subject', 'value': 'Antibodies', 'r...
# 50575  [{'name': 'subject', 'value': 'Coronavirus Omi...
# 50581  [{'name': 'subject', 'value': 'Politics and Go...
# 50587  [{'name': 'subject', 'value': 'English Languag...
# 50592  [{'name': 'subject', 'value': 'Coronavirus Omi...
#
#                        pub_date document_type   news_desk section_name  \
# 11     2021-01-01T03:44:59+0000       article     Foreign        World
# 16     2021-01-01T08:00:06+0000       article       Metro     New York
# 18     2021-01-01T10:00:02+0000    multimedia        Well         Well
# 24     2021-01-01T10:00:13+0000       article        Well         Well
# 47     2021-01-01T13:00:09+0000       article  RealEstate  Real Estate
# ...                         ...           ...         ...          ...
# 50566  2021-11-30T16:03:10+0000       article     Science       Health
# 50575  2021-11-30T17:08:17+0000       article     Science       Health
# 50581  2021-11-30T18:14:44+0000       article     Foreign        World
# 50587  2021-11-30T18:51:06+0000       article     Express        World
# 50592  2021-11-30T19:34:18+0000       article  Washington         U.S.
#
#                                                   byline     type_of_material  \
# 11     {'original': 'By Allyson Waller', 'person': [{...                 News
# 16     {'original': 'By Joseph Goldstein', 'person': ...                 News
# 18     {'original': 'By Toby Bilanow', 'person': [{'f...  Interactive Feature
# 24     {'original': 'By Tara Parker-Pope', 'person': ...                 News
# 47     {'original': 'By Ronda Kaysen', 'person': [{'f...                 News
# ...                                                  ...                  ...
# 50566  {'original': 'By Benjamin Mueller', 'person': ...                 News
# 50575  {'original': 'By Andrew Jacobs', 'person': [{'...                 News
# 50581  {'original': 'By Mark Landler and Megan Specia...                 News
# 50587  {'original': 'By Christine Hauser', 'person': ...                 News
# 50592  {'original': 'By Noah Weiland', 'person': [{'f...                 News
#
#                                                      _id word_count  \
# 11     nyt://article/c29df2db-63c0-5c92-b646-b4f6a09c...        265
# 16     nyt://article/f9171427-eed3-5031-88fa-f3ba050a...       1541
# 18     nyt://interactive/22b2316e-59ad-5af2-a53f-b7d3...          0
# 24     nyt://article/228e9d6c-c91d-5cfa-9ef6-ff1f8596...       1322
# 47     nyt://article/3f7df85e-2f30-50f8-b290-2221dba7...       1167
# ...                                                  ...        ...
# 50566  nyt://article/b5f7cdef-66e4-5d3d-94c7-dd42adb5...        319
# 50575  nyt://article/695d6348-43e1-52a1-a9d1-abff2b40...       1331
# 50581  nyt://article/2f9a2356-a67d-5263-b297-52b6e338...       1219
# 50587  nyt://article/e5022683-7baf-5cc1-8fe7-53dea5d4...        287
# 50592  nyt://article/324cab09-d56f-5fdf-9fb2-09ddcb1e...        619
#
#                                                      uri subsection_name
# 11     nyt://article/c29df2db-63c0-5c92-b646-b4f6a09c...             NaN
# 16     nyt://article/f9171427-eed3-5031-88fa-f3ba050a...             NaN
# 18     nyt://interactive/22b2316e-59ad-5af2-a53f-b7d3...            Live
# 24     nyt://article/228e9d6c-c91d-5cfa-9ef6-ff1f8596...            Live
# 47     nyt://article/3f7df85e-2f30-50f8-b290-2221dba7...             NaN
# ...                                                  ...             ...
# 50566  nyt://article/b5f7cdef-66e4-5d3d-94c7-dd42adb5...             NaN
# 50575  nyt://article/695d6348-43e1-52a1-a9d1-abff2b40...             NaN
# 50581  nyt://article/2f9a2356-a67d-5263-b297-52b6e338...          Europe
# 50587  nyt://article/e5022683-7baf-5cc1-8fe7-53dea5d4...             NaN
# 50592  nyt://article/324cab09-d56f-5fdf-9fb2-09ddcb1e...        Politics
#
# [6584 rows x 20 columns]

# %%
df5.drop(['web_url','snippet','lead_paragraph','print_section','print_page','source','multimedia','document_type','_id','uri'], axis=1, inplace=True)
# Out:
# /Users/ruijin/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df6=df5.filter(['abstract','headline','pub_date'])
df6.reset_index(drop=True, inplace=True)
df6
# Out:
#                                                abstract  \
# 0     a highly contagious coronavirus variant first ...
# 1     with a new variant of the virus emerging elsew...
# 2       test your knowledge of this week’s health news.
# 3     our 7-day well challenge will show you how to ...
# 4     the coronavirus has disrupted supply chains in...
# ...                                                 ...
# 6579  the company said that analyses and modeling of...
# 6580  intense research into the new coronavirus vari...
# 6581  britain’s approach to coronavirus-related rest...
# 6582  unlike alpha, beta and delta, the name of the ...
# 6583  the centers for disease control and prevention...
#
#                                                headline  \
# 0     florida health officials detect the state’s fi...
# 1     virus numbers are surging. why is new york’s v...
# 2     weekly health quiz: a new coronavirus variant,...
# 3     for a healthier 2021, keep the best habits of ...
# 4     furnishing your home in a pandemic will requir...
# ...                                                 ...
# 6579  regeneron says its antibody treatment may not ...
# 6580         omicron: what is known — and still unknown
# 6581  amid variant fears, u.k. discovers limits to i...
# 6582                          how do you say ‘omicron’?
# 6583  federal health officials say that they are exp...
#
#                       pub_date
# 0     2021-01-01T03:44:59+0000
# 1     2021-01-01T08:00:06+0000
# 2     2021-01-01T10:00:02+0000
# 3     2021-01-01T10:00:13+0000
# 4     2021-01-01T13:00:09+0000
# ...                        ...
# 6579  2021-11-30T16:03:10+0000
# 6580  2021-11-30T17:08:17+0000
# 6581  2021-11-30T18:14:44+0000
# 6582  2021-11-30T18:51:06+0000
# 6583  2021-11-30T19:34:18+0000
#
# [6584 rows x 3 columns]

# %%
df6['pub_date']= pd.to_datetime(df6['pub_date'], format = "%Y-%m-%d %H:%M:%S")
df6
# Out:
#                                                abstract  \
# 0     a highly contagious coronavirus variant first ...
# 1     with a new variant of the virus emerging elsew...
# 2       test your knowledge of this week’s health news.
# 3     our 7-day well challenge will show you how to ...
# 4     the coronavirus has disrupted supply chains in...
# ...                                                 ...
# 6579  the company said that analyses and modeling of...
# 6580  intense research into the new coronavirus vari...
# 6581  britain’s approach to coronavirus-related rest...
# 6582  unlike alpha, beta and delta, the name of the ...
# 6583  the centers for disease control and prevention...
#
#                                                headline  \
# 0     florida health officials detect the state’s fi...
# 1     virus numbers are surging. why is new york’s v...
# 2     weekly health quiz: a new coronavirus variant,...
# 3     for a healthier 2021, keep the best habits of ...
# 4     furnishing your home in a pandemic will requir...
# ...                                                 ...
# 6579  regeneron says its antibody treatment may not ...
# 6580         omicron: what is known — and still unknown
# 6581  amid variant fears, u.k. discovers limits to i...
# 6582                          how do you say ‘omicron’?
# 6583  federal health officials say that they are exp...
#
#                       pub_date
# 0    2021-01-01 03:44:59+00:00
# 1    2021-01-01 08:00:06+00:00
# 2    2021-01-01 10:00:02+00:00
# 3    2021-01-01 10:00:13+00:00
# 4    2021-01-01 13:00:09+00:00
# ...                        ...
# 6579 2021-11-30 16:03:10+00:00
# 6580 2021-11-30 17:08:17+00:00
# 6581 2021-11-30 18:14:44+00:00
# 6582 2021-11-30 18:51:06+00:00
# 6583 2021-11-30 19:34:18+00:00
#
# [6584 rows x 3 columns]

# %%
#Send dataframe to a CSV
df6.to_csv('data/NYTGeneraldata1.csv')

# %% [markdown]
# # Finance Data Yearly
# #### Getting yearly data using Alpha Vantage API for Pfizer(pfe), Moderna(mrna), AstraZeneca(azn)

# %%
key='HHU6WKJFGNX07KWW'

ts = TimeSeries(key = key, output_format = 'csv')

data_azn = ts.get_daily_adjusted(symbol = 'AZN', outputsize='full')
df_azn = pd.DataFrame(list(data_azn[0]))

header_row=0
df_azn.columns = df_azn.iloc[header_row]
df_azn = df_azn.drop(header_row)
#df_azn['day_of_week']=df_azn['timestamp'].dt.day_name()

df_azn
# Out:
# 0      timestamp   open    high    low  close adjusted_close   volume  \
# 1     2021-12-20  56.56   56.64   56.0  56.56          56.56  4098658
# 2     2021-12-17  56.57  56.995  55.96  56.02          56.02  6035602
# 3     2021-12-16  56.12  57.185  56.06  57.09          57.09  6855978
# 4     2021-12-15  54.94   55.75  54.64  55.72          55.72  4834671
# 5     2021-12-14  54.53   54.89  54.35   54.5           54.5  3585669
# ...          ...    ...     ...    ...    ...            ...      ...
# 5567  1999-11-05  46.31   46.44  45.44  45.69  10.0944041917   403000
# 5568  1999-11-04  45.13   45.94   44.5  45.38  10.0259151284   282800
# 5569  1999-11-03  45.44   45.63  44.38  45.31  10.0104498561   356000
# 5570  1999-11-02  44.75   44.75  43.88   44.0  9.72102833078   362100
# 5571  1999-11-01  45.75   45.81  45.25  45.44  10.0391710762   387500
#
# 0    dividend_amount split_coefficient
# 1             0.0000               1.0
# 2             0.0000               1.0
# 3             0.0000               1.0
# 4             0.0000               1.0
# 5             0.0000               1.0
# ...              ...               ...
# 5567          0.0000               1.0
# 5568          0.0000               1.0
# 5569          0.0000               1.0
# 5570          0.0000               1.0
# 5571          0.0000               1.0
#
# [5571 rows x 9 columns]

# %%
data_pfe = ts.get_daily_adjusted(symbol = 'PFE', outputsize='full')

df_pfe = pd.DataFrame(list(data_pfe[0]))

header_row=0
df_pfe.columns = df_pfe.iloc[header_row]
df_pfe = df_pfe.drop(header_row)

df_pfe
# Out:
# 0      timestamp   open    high     low  close adjusted_close     volume  \
# 1     2021-12-20   60.6   61.71   59.83  61.02          61.02   55712217
# 2     2021-12-17  59.93   61.19    58.7  59.48          59.48  104320166
# 3     2021-12-16  58.36   61.43   57.75  61.25          61.25   75183647
# 4     2021-12-15  56.11  58.915   55.89   58.8           58.8   75202914
# 5     2021-12-14  54.77   55.95  54.316  55.54          55.54   48685674
# ...          ...    ...     ...     ...    ...            ...        ...
# 5567  1999-11-05  36.25   36.25   34.25  34.75  15.5244869919   44375100
# 5568  1999-11-04  38.63   39.06    37.0  37.25  16.6413565596   14065500
# 5569  1999-11-03   39.0   39.31   38.38  38.56  17.2265962132    7114400
# 5570  1999-11-02  38.62   39.25   38.12  38.12  17.0300271692    6623800
# 5571  1999-11-01   39.5    40.0    38.5   38.5  17.1997913435    7053200
#
# 0    dividend_amount split_coefficient
# 1             0.0000               1.0
# 2             0.0000               1.0
# 3             0.0000               1.0
# 4             0.0000               1.0
# 5             0.0000               1.0
# ...              ...               ...
# 5567          0.0000               1.0
# 5568          0.0000               1.0
# 5569          0.0000               1.0
# 5570          0.0000               1.0
# 5571          0.0000               1.0
#
# [5571 rows x 9 columns]

# %%
data_mrna = ts.get_daily_adjusted(symbol = 'MRNA', outputsize='full')

df_mrna = pd.DataFrame(list(data_mrna[0]))

header_row=0
df_mrna.columns = df_mrna.iloc[header_row]
df_mrna = df_mrna.drop(header_row)


df_mrna
# Out:
# 0     timestamp      open      high       low   close adjusted_close  \
# 1    2021-12-20   321.305   321.305    275.12  276.38         276.38
# 2    2021-12-17    275.57    296.39     269.0   294.8          294.8
# 3    2021-12-16     284.2  287.1335    277.07  282.02         282.02
# 4    2021-12-15  271.7994    290.35    271.55  283.28         283.28
# 5    2021-12-14   264.295    278.33  257.2005  277.16         277.16
# ..          ...       ...       ...       ...     ...            ...
# 761  2018-12-13     19.25     19.29     18.68   18.76          18.76
# 762  2018-12-12     18.55     19.48     18.02   18.68          18.68
# 763  2018-12-11     20.55     20.66     17.99   18.01          18.01
# 764  2018-12-10      18.9    19.439      18.0    18.8           18.8
# 765  2018-12-07      22.0     22.75     18.51    18.6           18.6
#
# 0      volume dividend_amount split_coefficient
# 1    16985330          0.0000               1.0
# 2    10627523          0.0000               1.0
# 3     5974339          0.0000               1.0
# 4     9269533          0.0000               1.0
# 5     6444908          0.0000               1.0
# ..        ...             ...               ...
# 761   1608629          0.0000               1.0
# 762   2590873          0.0000               1.0
# 763   3435271          0.0000               1.0
# 764   4233345          0.0000               1.0
# 765  12995569          0.0000               1.0
#
# [765 rows x 9 columns]

# %% [markdown]
# #### Filtering data obtained above for AstraZeneca for the year 2021, getting percentage change in close price,converting the 'timestamp' column to datetime format and also adding a columns with name of days

# %%
azn = df_azn[df_azn.timestamp.str.contains("2021-")]
new_azn = azn[~azn.timestamp.str.contains("2021-12-")]
new_azn.sort_values('timestamp', inplace=True, axis=0, ignore_index=True)
azn_close = new_azn['adjusted_close']
new_azn["change"]= azn_close.astype(float).pct_change()
#change timestamp format
new_azn['timestamp']= pd.to_datetime(new_azn['timestamp'], format = "%Y-%m-%d %H:%M:%S", utc=True)
new_azn['day_of_week']=new_azn['timestamp'].dt.day_name()
# Out:
# <ipython-input-20-d29c1ffd762e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_azn.sort_values('timestamp', inplace=True, axis=0, ignore_index=True)
# <ipython-input-20-d29c1ffd762e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_azn["change"]= azn_close.astype(float).pct_change()
# <ipython-input-20-d29c1ffd762e>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_azn['timestamp']= pd.to_datetime(new_azn['timestamp'], format = "%Y-%m-%d %H:%M:%S", utc=True)
# <ipython-input-20-d29c1ffd762e>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_azn['day_of_week']=new_azn['timestamp'].dt.day_name()

# %% [markdown]
# #### Creating a new dataframe 'close', which only has "timestamp","day_of_week","adjusted_close" and "change" columns. Writing the new dataframe to csv file named 'AZN_close.csv'

# %%
close = new_azn[["timestamp","day_of_week","adjusted_close", "change"]]
close.to_csv('data/AZN_close.csv')

# %% [markdown]
# #### Filtering data obtained above for Pfizer for the year 2021, getting percentage change in close price, converting the 'timestamp' column to datetime format and and also adding a columns with name of days

# %%
#pd.to_numeric(df_pfe['adjusted_close'], downcast="float")
pfe = df_pfe[df_pfe.timestamp.str.contains("2021-")]
new_pfe = pfe[~pfe.timestamp.str.contains("2021-12-")]
new_pfe.sort_values('timestamp', inplace=True, axis=0, ignore_index=True)
pfe_close = new_pfe['adjusted_close']
new_pfe["change"]= pfe_close.astype(float).pct_change()

# #change timestamp format
new_pfe['timestamp']= pd.to_datetime(new_pfe['timestamp'], format = "%Y-%m-%d %H:%M:%S", utc=True)
new_pfe['day_of_week']=new_pfe['timestamp'].dt.day_name()
# Out:
# <ipython-input-22-c864fe9be082>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_pfe.sort_values('timestamp', inplace=True, axis=0, ignore_index=True)
# <ipython-input-22-c864fe9be082>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_pfe["change"]= pfe_close.astype(float).pct_change()
# <ipython-input-22-c864fe9be082>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_pfe['timestamp']= pd.to_datetime(new_pfe['timestamp'], format = "%Y-%m-%d %H:%M:%S", utc=True)
# <ipython-input-22-c864fe9be082>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_pfe['day_of_week']=new_pfe['timestamp'].dt.day_name()

# %% [markdown]
# #### Creating a new dataframe 'close', which only has "timestamp","day_of_week","adjusted_close" and "change" columns for Pfizer. Writing the new dataframe to csv file named 'PFE_close.csv'

# %%
close = new_pfe[["timestamp","day_of_week","adjusted_close", "change"]]
close.to_csv('data/PFE_close.csv')

# %% [markdown]
# #### Filtering data obtained above for Moderna for the year 2021, getting percentage change in close price, converting the 'timestamp' column to datetime format and and also adding a columns with name of days

# %%
mrna = df_mrna[df_mrna.timestamp.str.contains("2021-")]
new_mrna = mrna[~mrna.timestamp.str.contains("2021-12-")]
new_mrna.sort_values('timestamp', inplace=True, axis=0, ignore_index=True)
mrna_close = new_mrna['adjusted_close']
new_mrna["change"]= mrna_close.astype(float).pct_change()

#change timestamp format
new_mrna['timestamp']= pd.to_datetime(new_mrna['timestamp'], format = "%Y-%m-%d %H:%M:%S", utc=True)
new_mrna['day_of_week']=new_mrna['timestamp'].dt.day_name()
# Out:
# <ipython-input-24-99b38d92c816>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_mrna.sort_values('timestamp', inplace=True, axis=0, ignore_index=True)
# <ipython-input-24-99b38d92c816>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_mrna["change"]= mrna_close.astype(float).pct_change()
# <ipython-input-24-99b38d92c816>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_mrna['timestamp']= pd.to_datetime(new_mrna['timestamp'], format = "%Y-%m-%d %H:%M:%S", utc=True)
# <ipython-input-24-99b38d92c816>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_mrna['day_of_week']=new_mrna['timestamp'].dt.day_name()

# %% [markdown]
# #### Creating a new dataframe 'close', which only has "timestamp","day_of_week","adjusted_close" and "change" columns for Moderna. Writing the new dataframe to csv file named 'MRNA_close.csv'

# %%
close = new_mrna[["timestamp","day_of_week","adjusted_close", "change"]]
close.to_csv('data/MRNA_close.csv')

# %% [markdown]
# # Finance Data November 2021
# #### Using the same process as described above, but for the monthly data

# %%
#key='HHU6WKJFGNX07KWW'

#ts = TimeSeries(key = key, output_format = 'csv')

data_azn = ts.get_intraday_extended(symbol = 'AZN', interval = '5min', slice = 'year1month1')
df_azn = pd.DataFrame(list(data_azn[0]))

header_row=0
df_azn.columns = df_azn.iloc[header_row]
df_azn = df_azn.drop(header_row)

#show output
df_azn
# Out:
# 0                    time   open    high      low   close  volume
# 1     2021-12-20 18:05:00   56.6    56.6     56.6    56.6     100
# 2     2021-12-20 16:05:00  56.56   56.56    56.56   56.56   51160
# 3     2021-12-20 16:00:00  56.55   56.58    56.51   56.57  193022
# 4     2021-12-20 15:55:00  56.49  56.575    56.47  56.555  125128
# 5     2021-12-20 15:50:00  56.45  56.495  56.4036  56.485   77627
# ...                   ...    ...     ...      ...     ...     ...
# 2346  2021-11-22 05:00:00   56.8    56.8    56.79   56.79     900
# 2347  2021-11-22 04:45:00  56.94   56.94    56.91   56.91     951
# 2348  2021-11-22 04:20:00  57.14   57.14    57.14   57.14     400
# 2349  2021-11-22 04:15:00  57.14   57.14    57.14   57.14     800
# 2350  2021-11-22 04:05:00  57.14   57.14    57.14   57.14     622
#
# [2350 rows x 6 columns]

# %%
data_azn_add = ts.get_intraday_extended(symbol = 'AZN', interval = '5min', slice = 'year1month2')

df_azn_add = pd.DataFrame(list(data_azn_add[0]))

header_row=0
df_azn_add.columns = df_azn_add.iloc[header_row]
df_azn_add = df_azn_add.drop(header_row)

#show output
print(df_azn_add)
# Out:
# 0                    time   open    high     low   close  volume
# 1     2021-11-19 19:35:00  56.86   56.88   56.86   56.88     500
# 2     2021-11-19 19:30:00   56.8   56.85    56.8   56.85     489
# 3     2021-11-19 16:05:00  56.66   56.66   56.66   56.66    7037
# 4     2021-11-19 16:00:00  56.68    56.7  56.645   56.66  182269
# 5     2021-11-19 15:55:00  56.64  56.705  56.625  56.685  126365
# ...                   ...    ...     ...     ...     ...     ...
# 2335  2021-10-22 07:30:00   62.0   62.02    62.0   62.02     908
# 2336  2021-10-22 07:25:00  61.98   61.99   61.96   61.97    3300
# 2337  2021-10-22 07:15:00  61.95   62.03   61.95   61.99    4268
# 2338  2021-10-22 07:10:00  61.93   61.98   61.93   61.98     706
# 2339  2021-10-22 07:05:00  61.81   61.85   61.81   61.84    7524
#
# [2339 rows x 6 columns]

# %%
data_pfe = ts.get_intraday_extended(symbol = 'PFE', interval = '5min', slice = 'year1month1')

df_pfe = pd.DataFrame(list(data_pfe[0]))

header_row=0
df_pfe.columns = df_pfe.iloc[header_row]
df_pfe = df_pfe.drop(header_row)

#show output
print(df_pfe)
# Out:
# 0                    time     open     high      low  close volume
# 1     2021-12-20 20:00:00    60.82    60.87    60.82  60.83   3750
# 2     2021-12-20 19:55:00    60.83    60.83  60.8001  60.82   3018
# 3     2021-12-20 19:50:00  60.8699  60.8699    60.83  60.83    530
# 4     2021-12-20 19:45:00    60.85    60.85    60.85  60.85   3169
# 5     2021-12-20 19:40:00    60.85    60.85    60.85  60.85    885
# ...                   ...      ...      ...      ...    ...    ...
# 3516  2021-11-22 04:25:00     51.2     51.2     51.2   51.2    342
# 3517  2021-11-22 04:20:00    51.09    51.12    51.05  51.11   5868
# 3518  2021-11-22 04:15:00    51.03    51.03    51.03  51.03    361
# 3519  2021-11-22 04:10:00    51.02    51.05    51.02  51.05   2658
# 3520  2021-11-22 04:05:00    51.02    51.03    51.02  51.03    681
#
# [3520 rows x 6 columns]

# %%
data_pfe_add = ts.get_intraday_extended(symbol = 'PFE', interval = '5min', slice = 'year1month2')

df_pfe_add = pd.DataFrame(list(data_pfe_add[0]))

header_row=0
df_pfe_add.columns = df_pfe_add.iloc[header_row]
df_pfe_add = df_pfe_add.drop(header_row)

#show output
print(df_pfe_add)
# Out:
# 0                    time           open           high            low  \
# 1     2021-11-19 20:00:00          50.94        50.9999          50.94
# 2     2021-11-19 19:55:00          50.91          50.95          50.91
# 3     2021-11-19 19:50:00        50.9501        50.9501          50.92
# 4     2021-11-19 19:40:00          50.98           51.0          50.98
# 5     2021-11-19 19:35:00          50.99           51.0          50.99
# ...                   ...            ...            ...            ...
# 3522  2021-10-22 05:20:00   42.541636528   42.541636528   42.541636528
# 3523  2021-10-22 05:10:00  42.5218128391  42.5218128391  42.5218128391
# 3524  2021-10-22 05:05:00  42.5119009946  42.5119009946  42.5119009946
# 3525  2021-10-22 05:00:00   42.581283906   42.581283906  42.5713720615
# 3526  2021-10-22 04:10:00  42.6209312839  42.6209312839  42.6209312839
#
# 0             close volume
# 1             50.94   5057
# 2             50.94   2950
# 3             50.93   2814
# 4              51.0    955
# 5              51.0    525
# ...             ...    ...
# 3522   42.541636528    283
# 3523  42.5218128391    121
# 3524  42.5119009946    116
# 3525  42.5713720615    340
# 3526  42.6209312839    355
#
# [3526 rows x 6 columns]

# %%
data_mrna = ts.get_intraday_extended(symbol = 'MRNA', interval = '5min', slice = 'year1month1')

df_mrna = pd.DataFrame(list(data_mrna[0]))

header_row=0
df_mrna.columns = df_mrna.iloc[header_row]
df_mrna = df_mrna.drop(header_row)

#show output
df_mrna
# Out:
# 0                    time      open      high     low     close volume
# 1     2021-12-20 20:00:00    276.73     277.0   276.5     276.5   3052
# 2     2021-12-20 19:55:00    276.11  276.4999   276.0  276.4999   2830
# 3     2021-12-20 19:50:00  276.3799     276.5  276.33    276.33   1534
# 4     2021-12-20 19:45:00  276.6999    276.83  276.51    276.51   1071
# 5     2021-12-20 19:40:00    276.54    276.84  276.54    276.84    266
# ...                   ...       ...       ...     ...       ...    ...
# 3173  2021-11-22 04:25:00    269.48    270.99  269.48    270.99   2638
# 3174  2021-11-22 04:20:00    269.09     269.5   269.0     269.5    906
# 3175  2021-11-22 04:15:00     268.6     269.5   268.6    269.11   2380
# 3176  2021-11-22 04:10:00    268.85    268.85  268.51    268.51    734
# 3177  2021-11-22 04:05:00    268.57     269.1   268.0     269.0   8434
#
# [3177 rows x 6 columns]

# %%
data_mrna_add = ts.get_intraday_extended(symbol = 'MRNA', interval = '5min', slice = 'year1month2')

df_mrna_add = pd.DataFrame(list(data_mrna_add[0]))

header_row=0
df_mrna_add.columns = df_mrna_add.iloc[header_row]
df_mrna_add = df_mrna_add.drop(header_row)


#show output
df_mrna_add
# Out:
# 0                    time    open      high     low   close volume
# 1     2021-11-19 20:00:00   263.0  263.3999   262.6   262.6   1280
# 2     2021-11-19 19:55:00   262.8     262.8   262.8   262.8    508
# 3     2021-11-19 19:45:00   263.2     263.2   263.2   263.2    102
# 4     2021-11-19 19:40:00  262.75    262.99  262.75  262.99   1146
# 5     2021-11-19 19:35:00  262.75    262.75  262.75  262.75    161
# ...                   ...     ...       ...     ...     ...    ...
# 3042  2021-10-22 04:30:00  332.85    332.85  332.85  332.85    102
# 3043  2021-10-22 04:20:00  332.88    332.88  332.88  332.88    333
# 3044  2021-10-22 04:15:00  332.01    332.01   332.0   332.0    512
# 3045  2021-10-22 04:10:00   333.1     333.5   332.0   333.5   1662
# 3046  2021-10-22 04:05:00  336.21    336.21   332.9   332.9   3800
#
# [3046 rows x 6 columns]

# %%
astrazeneca = [df_azn, df_azn_add]
azn = pd.concat(astrazeneca)
azn_new = azn[~azn.time.str.contains("2021-12-")]
final_azn = azn_new[~azn_new.time.str.contains("2021-10-")]
final_azn.sort_values("time", inplace = True)
final_azn.set_index("time", inplace = True)
final_azn["change"]= final_azn.close.astype(float).pct_change()
final_azn = final_azn[["close", "change"]]
final_azn.to_csv('data/AZN_monthly.csv')
# Out:
# <ipython-input-32-a1663ce71266>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_azn.sort_values("time", inplace = True)
# <ipython-input-32-a1663ce71266>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_azn["change"]= final_azn.close.astype(float).pct_change()

# %%
pfizer = [df_pfe, df_pfe_add]
pfe = pd.concat(pfizer)
pfe_new = pfe[~pfe.time.str.contains("2021-12-")]
final_pfe = pfe_new[~pfe_new.time.str.contains("2021-10-")]
final_pfe.sort_values("time", inplace = True)
final_pfe.set_index("time", inplace = True)
final_pfe["change"]= final_pfe.close.astype(float).pct_change()
final_pfe = final_pfe[["close", "change"]]
final_pfe.to_csv('data/PFE_monthly.csv')
# Out:
# <ipython-input-43-7ecb45f3002d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_pfe.sort_values("time", inplace = True)
# <ipython-input-43-7ecb45f3002d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_pfe["change"]= final_pfe.close.astype(float).pct_change()

# %%
moderna = [df_mrna, df_mrna_add]
mrna = pd.concat(moderna)
mrna_new = mrna[~mrna.time.str.contains("2021-12-")]
final_mrna = mrna_new[~mrna_new.time.str.contains("2021-10-")]
final_mrna.sort_values("time", inplace = True)
final_mrna.set_index("time", inplace = True)
final_mrna["change"]= final_mrna.close.astype(float).pct_change()
final_mrna = final_mrna[["close", "change"]]
final_mrna.to_csv('data/MRNA_monthly.csv')
# Out:
# <ipython-input-34-daac3d4707a5>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_mrna.sort_values("time", inplace = True)
# <ipython-input-34-daac3d4707a5>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_mrna["change"]= final_mrna.close.astype(float).pct_change()

# %% [markdown]
# # Guardian data

# %% [markdown]
# ### Occurrence analysis data

# %% [markdown]
# #### Extracting headlines and published dates of articles about covid from the Guardian API, sending to a CSV called 'Guardian_articles_covid.csv'. This will later be used in occurrence analysis, to determine how often covid-related words appear in headlines over time.

# %% [markdown]
# NB You may need to restart the kernel and run this cell again if you run into errors - this is due to an issue with the API.

# %%
# File to put API responses into
response_file = open('data/Guardian_articles_covid.csv','w')
from_date = '2021-01-01'
end_date = '2021-12-09'
query = 'covid'

# Get number of pages returned by response (so can loop through them later).
API_Key = '6e7020bf-248a-4bbf-840d-3b737649c9f8' #Put personal API key here
URL_1 = 'https://content.guardianapis.com/search?from-date={}&to-date={}&q={}&page-size=200&page=1&api-key={}'.format(from_date,end_date,query,API_Key)
responses_1 = (requests.request("GET", URL_1)).json()
no_of_pages = responses_1['response']['pages']
no_of_results = responses_1['response']['total']
print("No. of pages = "+str(no_of_pages))
print("No. of results = "+str(no_of_results))
response_file.write('Title,DateTimePublished\n')

# Loop through pages and through results in each page, write title (headline) to csv

for i in range(1, no_of_pages+1):
    URL = 'https://content.guardianapis.com/search?from-date={}&to-date={}&page-size=200&q={}&page={}&api-key={}'.format(from_date,end_date,query,
        i, API_Key)
    responses = (requests.request("GET", URL)).json()
    #print(responses)
    try:
        status = responses['response']['status']
        page = responses['response']['currentPage']
    except KeyError as err:
        print('Error: '+ str(err))
        pass
    if status == 'ok' and page != no_of_pages:
        for j in range(0, 199):
            x = responses['response']['results'][j]['webTitle']
            title = (re.sub(r'[^\w\s]', '', x)).lower()
            date = responses['response']['results'][j]['webPublicationDate']
            response_file.write(title +','+date + '\n')
    else:
        #print(status)
        for j in range(0, no_of_results%200):
            try:
                x = responses['response']['results'][j]['webTitle']
                title = (re.sub(r'[^\w\s]', '', x)).lower()
                response_file.write(title + ',' + date + '\n')
            except IndexError or KeyError as err1:
                print("Error: "+str(err1))
# Out:
# No. of pages = 114
# No. of results = 22736
# Error: 'currentPage'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-c3b2fe69c80a> in <module>
#      38         for j in range(0, no_of_results%200):
#      39             try:
# ---> 40                 x = responses['response']['results'][j]['webTitle']
#      41                 title = (re.sub(r'[^\w\s]', '', x)).lower()
#      42                 response_file.write(title + ',' + date + '\n')
#
# KeyError: 'results'

# %% [markdown]
# ### Word Cloud data

# %% [markdown]
# #### Extracting all Guardian article headlines published each quarter of 2021 and putting them into separate CSVs (called 'Guardian_articles_Qn.csv'. This will later be used to build word clouds showing the most mentioned words in the news each quarter.

# %%
# Defining a function to extract all Guardian headlines from the Guardian API, given a start and end date, and a file to put the responses into
def extract_headlines(response_file, from_date, end_date):
    # # Get number of pages returned by response (so can loop through them later).
    API_Key = '28e80572-27de-49b8-a096-6725a36b9bab' #Put personal API key here
    URL_1 = 'https://content.guardianapis.com/search?from-date={}&to-date={}&page-size=200&page=1&api-key={}'.format(from_date,end_date,API_Key)
    responses_1 = (requests.request("GET", URL_1)).json()
    no_of_pages = responses_1['response']['pages']
    no_of_results = responses_1['response']['total']
    
# Print no. of pages and results to the console as a check
    print("No. of pages = "+str(no_of_pages))
    print("No. of results = "+str(no_of_results))

    # Loop through pages and through results in each page, write title to csv

    for i in range(1, no_of_pages+1):
        URL = 'https://content.guardianapis.com/search?from-date={}&to-date={}&page-size=200&page={}&api-key={}'.format(from_date,end_date,
            i, API_Key)
        responses = (requests.request("GET", URL)).json()
        try:
            status = responses['response']['status']
            page = responses['response']['currentPage']
        except KeyError as err:
            print('Error: '+ err)
        if status == 'ok' and page != no_of_pages:
            for j in range(0, 199):
                title = (responses['response']['results'][j]['webTitle'])
                response_file.write(title + '\n')
        else:
            for j in range(0, no_of_results%200):
                try:
                    title = responses['response']['results'][j]['webTitle']
                    response_file.write(title + '\n')
                except IndexError as err1:
                    print("Error: "+str(err1))

# %%
# Q1
extract_headlines(response_file = (open('data/Guardian_articles_Q1.csv','w')), from_date = '2021-01-01', end_date = '2021-03-31')
# Out:
# No. of pages = 96
# No. of results = 19028

# %%
# Q2
extract_headlines(response_file = (open('data/Guardian_articles_Q2.csv','w')), from_date = '2021-04-01', end_date = '2021-06-30')
# Out:
# No. of pages = 97
# No. of results = 19203

# %%
# Q3
extract_headlines(response_file = (open('data/Guardian_articles_Q3.csv','w')), from_date = '2021-07-01', end_date = '2021-09-30')
# Out:
# No. of pages = 97
# No. of results = 19245

# %%
# Q4 - NB cut off of 12th December used, as this is when our analysis was conducted
extract_headlines(response_file = (open('data/Guardian_articles_Q4.csv','w')), from_date = '2021-10-01', end_date = '2021-12-12')
# Out:
# No. of pages = 81
# No. of results = 16017

# %% [markdown]
# #### Getting word frequencies from headline articles each quarter - using the 4 CSVs made previously, and creating a CSV for each quarter, with words and the number of times they appear in the CSV

# %%
# List of irrelevant words to exclude from analysis
filler_words = ['crossword','amid','way','over','could','day','years','into','may','must','right','been','go','week','time','make','back','happened','so','do','our','about','but','if','now','should','off','our','cant','got','have','dont','than','more','get','an','does','just','say','take','met','had','be','im','like','isnt','any','some','meet','were','them','this','then','from','two','three','how','out','are','said','can','with','is','me','says','all','we','no','was','that','not','one','its','us','has','my','will','on','in','they','their','you','your','by','at','and','a','i','because','it','too','to','for','of','his','her','he','him','she','the','or','before','after','as','why','what','who','when']


def extract_word_frequencies(input_file,output_file):
    string_file = input_file.read()

    # Cleaning data - removing punctuation, making all lower case, getting rid of line breaks and turning into list
    stripped_response = (re.sub(r'[^\w\s]', '', string_file)).lower()
    new_stripped_response = stripped_response.replace("\n"," ")
    words = new_stripped_response.split(" ")

    # Making empty dictionary to add to later, turning list of words into set (so we get unique set of words to list through)
    dictionary = {}
    set_of_words = set(words)

    # Looping through set of words (excluding numbers and filler words) and getting count - adding the results to a dictionary
    for i in set_of_words:
        if i.isalpha() and i not in filler_words:
            dictionary.update({i: words.count(i)})

    # Only showing words which appear more than 40 times
    shorter_dict = {k:v for (k,v) in dictionary.items() if v > 40}

    # Sort list by word count descending (make into list to do this, then back into dictionary)
    marklist = sorted(shorter_dict.items(), key=lambda x:x[1], reverse=True)
    sorted_dict = dict(marklist)

    with output_file as f:
        writer = csv.writer(f)
        f.write("Word,Count\n")
        for k, v in sorted_dict.items():
           writer.writerow([k, v])

# %%
# Q1
extract_word_frequencies(input_file = open('data/Guardian_articles_Q1.csv','r'), output_file = open('Q1_Analysis.csv', 'w'))

# %%
# Q2
extract_word_frequencies(input_file = open('data/Guardian_articles_Q2.csv','r'), output_file = open('Q2_Analysis.csv', 'w'))

# %%
# Q3
extract_word_frequencies(input_file = open('data/Guardian_articles_Q3.csv','r'), output_file = open('Q3_Analysis.csv', 'w'))

# %%
# Q4
extract_word_frequencies(input_file = open('data/Guardian_articles_Q4.csv','r'), output_file = open('Q4_Analysis.csv', 'w'))
